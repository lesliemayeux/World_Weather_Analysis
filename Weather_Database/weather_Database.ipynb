# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 746

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | jumla
# Processing Record 2 of the Set 1 | pombia
# Processing Record 3 of the Set 1 | ushuaia
# Processing Record 4 of the Set 1 | samusu
# City not found. Skipping...
# Processing Record 5 of the Set 1 | busselton
# Processing Record 6 of the Set 1 | vaini
# Processing Record 7 of the Set 1 | comodoro rivadavia
# Processing Record 8 of the Set 1 | clyde river
# Processing Record 9 of the Set 1 | saint anthony
# Processing Record 10 of the Set 1 | komsomolskiy
# Processing Record 11 of the Set 1 | oussouye
# Processing Record 12 of the Set 1 | caxito
# Processing Record 13 of the Set 1 | rikitea
# Processing Record 14 of the Set 1 | pisco
# Processing Record 15 of the Set 1 | hobart
# Processing Record 16 of the Set 1 | tiksi
# Processing Record 17 of the Set 1 | umm lajj
# Processing Record 18 of the Set 1 | chokurdakh
# Processing Record 19 of the Set 1 | jamestown
# Processing Record 20 of the Set 1 | nurota
# Processing Record 21 of the Set 1 | mataura
# Processing Record 22 of the Set 1 | alekseyevka
# Processing Record 23 of the Set 1 | nouakchott
# Processing Record 24 of the Set 1 | tuktoyaktuk
# Processing Record 25 of the Set 1 | hithadhoo
# Processing Record 26 of the Set 1 | baykit
# Processing Record 27 of the Set 1 | thompson
# Processing Record 28 of the Set 1 | bluff
# Processing Record 29 of the Set 1 | coihaique
# Processing Record 30 of the Set 1 | cruces
# Processing Record 31 of the Set 1 | marienburg
# Processing Record 32 of the Set 1 | cayenne
# Processing Record 33 of the Set 1 | dingle
# Processing Record 34 of the Set 1 | avarua
# Processing Record 35 of the Set 1 | bo rai
# Processing Record 36 of the Set 1 | warrnambool
# Processing Record 37 of the Set 1 | leningradskiy
# Processing Record 38 of the Set 1 | yellowknife
# Processing Record 39 of the Set 1 | tonj
# Processing Record 40 of the Set 1 | qaanaaq
# Processing Record 41 of the Set 1 | belmonte
# Processing Record 42 of the Set 1 | pasighat
# Processing Record 43 of the Set 1 | bredasdorp
# Processing Record 44 of the Set 1 | atuona
# Processing Record 45 of the Set 1 | tasiilaq
# Processing Record 46 of the Set 1 | mar del plata
# Processing Record 47 of the Set 1 | port macquarie
# Processing Record 48 of the Set 1 | burnie
# Processing Record 49 of the Set 1 | katsuura
# Processing Record 50 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of the Set 2 | bethel
# Processing Record 2 of the Set 2 | sabang
# Processing Record 3 of the Set 2 | puerto ayora
# Processing Record 4 of the Set 2 | palenque
# Processing Record 5 of the Set 2 | acapulco
# Processing Record 6 of the Set 2 | port hedland
# Processing Record 7 of the Set 2 | tual
# Processing Record 8 of the Set 2 | cape town
# Processing Record 9 of the Set 2 | port alfred
# Processing Record 10 of the Set 2 | new norfolk
# Processing Record 11 of the Set 2 | bathsheba
# Processing Record 12 of the Set 2 | nogent-le-rotrou
# Processing Record 13 of the Set 2 | flinders
# Processing Record 14 of the Set 2 | sao joao da barra
# Processing Record 15 of the Set 2 | yaan
# Processing Record 16 of the Set 2 | bombay
# Processing Record 17 of the Set 2 | albany
# Processing Record 18 of the Set 2 | lorengau
# Processing Record 19 of the Set 2 | punta arenas
# Processing Record 20 of the Set 2 | seoul
# Processing Record 21 of the Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of the Set 2 | umzimvubu
# Processing Record 23 of the Set 2 | maua
# Processing Record 24 of the Set 2 | tongliao
# Processing Record 25 of the Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 26 of the Set 2 | polson
# Processing Record 27 of the Set 2 | cherskiy
# Processing Record 28 of the Set 2 | teknaf
# Processing Record 29 of the Set 2 | buqayq
# Processing Record 30 of the Set 2 | mattru
# Processing Record 31 of the Set 2 | sao filipe
# Processing Record 32 of the Set 2 | walvis bay
# Processing Record 33 of the Set 2 | sakakah
# Processing Record 34 of the Set 2 | toftir
# City not found. Skipping...
# Processing Record 35 of the Set 2 | nguiu
# Processing Record 36 of the Set 2 | svetlogorsk
# Processing Record 37 of the Set 2 | yendi
# Processing Record 38 of the Set 2 | urucara
# Processing Record 39 of the Set 2 | asau
# Processing Record 40 of the Set 2 | saleaula
# City not found. Skipping...
# Processing Record 41 of the Set 2 | butaritari
# Processing Record 42 of the Set 2 | nikolskoye
# Processing Record 43 of the Set 2 | ahuimanu
# Processing Record 44 of the Set 2 | kalmunai
# Processing Record 45 of the Set 2 | kruisfontein
# Processing Record 46 of the Set 2 | nishihara
# Processing Record 47 of the Set 2 | saskylakh
# Processing Record 48 of the Set 2 | grindavik
# Processing Record 49 of the Set 2 | vostok
# Processing Record 50 of the Set 2 | hermanus
# Processing Record 1 of the Set 3 | kapaa
# Processing Record 2 of the Set 3 | codrington
# Processing Record 3 of the Set 3 | atasu
# Processing Record 4 of the Set 3 | yamada
# Processing Record 5 of the Set 3 | cockburn town
# Processing Record 6 of the Set 3 | tucano
# Processing Record 7 of the Set 3 | wewak
# Processing Record 8 of the Set 3 | helmstedt
# Processing Record 9 of the Set 3 | khatanga
# Processing Record 10 of the Set 3 | massakory
# Processing Record 11 of the Set 3 | yumen
# Processing Record 12 of the Set 3 | san patricio
# Processing Record 13 of the Set 3 | jamestown
# Processing Record 14 of the Set 3 | husavik
# Processing Record 15 of the Set 3 | nushki
# Processing Record 16 of the Set 3 | whitecourt
# Processing Record 17 of the Set 3 | lata
# Processing Record 18 of the Set 3 | pacific grove
# Processing Record 19 of the Set 3 | great yarmouth
# Processing Record 20 of the Set 3 | tautira
# Processing Record 21 of the Set 3 | cidreira
# Processing Record 22 of the Set 3 | lincoln
# Processing Record 23 of the Set 3 | rungata
# Processing Record 24 of the Set 3 | margate
# Processing Record 25 of the Set 3 | port elizabeth
# Processing Record 26 of the Set 3 | vardo
# Processing Record 27 of the Set 3 | cherat
# Processing Record 28 of the Set 3 | east london
# Processing Record 29 of the Set 3 | manzhouli
# Processing Record 30 of the Set 3 | varhaug
# Processing Record 31 of the Set 3 | upernavik
# Processing Record 32 of the Set 3 | fereydunshahr
# Processing Record 33 of the Set 3 | attock
# Processing Record 34 of the Set 3 | hualmay
# Processing Record 35 of the Set 3 | churapcha
# Processing Record 36 of the Set 3 | vestmannaeyjar
# Processing Record 37 of the Set 3 | buchanan
# Processing Record 38 of the Set 3 | bibiani
# Processing Record 39 of the Set 3 | aklavik
# Processing Record 40 of the Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 41 of the Set 3 | hilo
# Processing Record 42 of the Set 3 | jalu
# Processing Record 43 of the Set 3 | xiaoweizhai
# Processing Record 44 of the Set 3 | palabuhanratu
# Processing Record 45 of the Set 3 | fukue
# Processing Record 46 of the Set 3 | ahipara
# Processing Record 47 of the Set 3 | la ronge
# Processing Record 48 of the Set 3 | bambous virieux
# Processing Record 49 of the Set 3 | tapejara
# Processing Record 50 of the Set 3 | sovetskiy
# Processing Record 1 of the Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of the Set 4 | lagoa
# Processing Record 3 of the Set 4 | xuddur
# Processing Record 4 of the Set 4 | norman wells
# Processing Record 5 of the Set 4 | mahon
# Processing Record 6 of the Set 4 | padang
# Processing Record 7 of the Set 4 | coquimbo
# Processing Record 8 of the Set 4 | primorsko-akhtarsk
# Processing Record 9 of the Set 4 | palimbang
# City not found. Skipping...
# Processing Record 10 of the Set 4 | ilhabela
# Processing Record 11 of the Set 4 | sahuaripa
# Processing Record 12 of the Set 4 | kasempa
# Processing Record 13 of the Set 4 | aykhal
# Processing Record 14 of the Set 4 | huarmey
# Processing Record 15 of the Set 4 | geraldton
# Processing Record 16 of the Set 4 | mahebourg
# Processing Record 17 of the Set 4 | havoysund
# Processing Record 18 of the Set 4 | riyadh
# Processing Record 19 of the Set 4 | hambantota
# Processing Record 20 of the Set 4 | almendralejo
# Processing Record 21 of the Set 4 | bengkulu
# Processing Record 22 of the Set 4 | castro
# Processing Record 23 of the Set 4 | barrow
# Processing Record 24 of the Set 4 | guerrero negro
# Processing Record 25 of the Set 4 | tarudant
# City not found. Skipping...
# Processing Record 26 of the Set 4 | kamyshin
# Processing Record 27 of the Set 4 | praya
# Processing Record 28 of the Set 4 | suffolk
# Processing Record 29 of the Set 4 | belaya gora
# Processing Record 30 of the Set 4 | pevek
# Processing Record 31 of the Set 4 | wajima
# Processing Record 32 of the Set 4 | parkersburg
# Processing Record 33 of the Set 4 | pangnirtung
# Processing Record 34 of the Set 4 | kaitangata
# Processing Record 35 of the Set 4 | mount isa
# Processing Record 36 of the Set 4 | salinas
# Processing Record 37 of the Set 4 | gasa
# Processing Record 38 of the Set 4 | luderitz
# Processing Record 39 of the Set 4 | chiang mai
# Processing Record 40 of the Set 4 | tuatapere
# Processing Record 41 of the Set 4 | peniche
# Processing Record 42 of the Set 4 | airai
# Processing Record 43 of the Set 4 | mys shmidta
# Processing Record 44 of the Set 4 | ust-kut
# Processing Record 45 of the Set 4 | poum
# Processing Record 46 of the Set 4 | minab
# Processing Record 47 of the Set 4 | ponta do sol
# Processing Record 48 of the Set 4 | kanniyakumari
# Processing Record 49 of the Set 4 | krasnoselkup
# Processing Record 50 of the Set 4 | manta
# Processing Record 1 of the Set 5 | palmerston
# Processing Record 2 of the Set 5 | rawson
# Processing Record 3 of the Set 5 | bagdarin
# Processing Record 4 of the Set 5 | matay
# Processing Record 5 of the Set 5 | salaya
# Processing Record 6 of the Set 5 | xiaoshi
# Processing Record 7 of the Set 5 | ancud
# Processing Record 8 of the Set 5 | attawapiskat
# Processing Record 9 of the Set 5 | saint-philippe
# Processing Record 10 of the Set 5 | haines junction
# Processing Record 11 of the Set 5 | bjelovar
# Processing Record 12 of the Set 5 | esso
# Processing Record 13 of the Set 5 | bridlicna
# Processing Record 14 of the Set 5 | marcona
# Processing Record 15 of the Set 5 | tuy hoa
# Processing Record 16 of the Set 5 | arraial do cabo
# Processing Record 17 of the Set 5 | ipeti
# City not found. Skipping...
# Processing Record 18 of the Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 19 of the Set 5 | barabai
# Processing Record 20 of the Set 5 | camacha
# Processing Record 21 of the Set 5 | iqaluit
# Processing Record 22 of the Set 5 | raahe
# Processing Record 23 of the Set 5 | hauge
# Processing Record 24 of the Set 5 | mednogorskiy
# Processing Record 25 of the Set 5 | playa vicente
# Processing Record 26 of the Set 5 | torbay
# Processing Record 27 of the Set 5 | sitka
# Processing Record 28 of the Set 5 | kenai
# Processing Record 29 of the Set 5 | phan rang
# Processing Record 30 of the Set 5 | chuy
# Processing Record 31 of the Set 5 | adrar
# Processing Record 32 of the Set 5 | santa maria
# Processing Record 33 of the Set 5 | grand river south east
# Processing Record 34 of the Set 5 | amderma
# Processing Record 35 of the Set 5 | fairbanks
# Processing Record 36 of the Set 5 | sentyabrskiy
# Processing Record 37 of the Set 5 | pangai
# Processing Record 38 of the Set 5 | ilulissat
# Processing Record 39 of the Set 5 | kayerkan
# Processing Record 40 of the Set 5 | vanimo
# Processing Record 41 of the Set 5 | mitu
# Processing Record 42 of the Set 5 | cochrane
# Processing Record 43 of the Set 5 | levelland
# Processing Record 44 of the Set 5 | lar gerd
# City not found. Skipping...
# Processing Record 45 of the Set 5 | severo-kurilsk
# Processing Record 46 of the Set 5 | rio grande
# Processing Record 47 of the Set 5 | kavieng
# Processing Record 48 of the Set 5 | nanakuli
# Processing Record 49 of the Set 5 | longyearbyen
# City not found. Skipping...
# Processing Record 50 of the Set 5 | balakhta
# Processing Record 1 of the Set 6 | yongan
# Processing Record 2 of the Set 6 | santo amaro da imperatriz
# Processing Record 3 of the Set 6 | blagodatnoye
# Processing Record 4 of the Set 6 | lugazi
# Processing Record 5 of the Set 6 | fort nelson
# Processing Record 6 of the Set 6 | kahului
# Processing Record 7 of the Set 6 | lavrentiya
# Processing Record 8 of the Set 6 | maghama
# Processing Record 9 of the Set 6 | lamas
# Processing Record 10 of the Set 6 | ribeira grande
# Processing Record 11 of the Set 6 | tete
# Processing Record 12 of the Set 6 | lohardaga
# Processing Record 13 of the Set 6 | buraydah
# Processing Record 14 of the Set 6 | portadown
# Processing Record 15 of the Set 6 | narsaq
# Processing Record 16 of the Set 6 | sao francisco
# Processing Record 17 of the Set 6 | rehoboth
# Processing Record 18 of the Set 6 | klaksvik
# City not found. Skipping...
# Processing Record 19 of the Set 6 | fort myers beach
# Processing Record 20 of the Set 6 | lemesos
# City not found. Skipping...
# Processing Record 21 of the Set 6 | nizhneyansk
# Processing Record 22 of the Set 6 | bhinga
# Processing Record 23 of the Set 6 | kuche
# Processing Record 24 of the Set 6 | illoqqortoormiut
# Processing Record 25 of the Set 6 | aksu
# Processing Record 26 of the Set 6 | hinesville
# Processing Record 27 of the Set 6 | victor harbor
# Processing Record 28 of the Set 6 | puerto baquerizo moreno
# Processing Record 29 of the Set 6 | natal
# Processing Record 30 of the Set 6 | sahrak
# City not found. Skipping...
# Processing Record 31 of the Set 6 | imbituba
# Processing Record 32 of the Set 6 | victoria point
# Processing Record 33 of the Set 6 | port lincoln
# Processing Record 34 of the Set 6 | shaunavon
# Processing Record 35 of the Set 6 | mantua
# Processing Record 36 of the Set 6 | oktyabrskiy
# Processing Record 37 of the Set 6 | shingu
# Processing Record 38 of the Set 6 | nouadhibou
# Processing Record 39 of the Set 6 | touros
# Processing Record 40 of the Set 6 | nea alikarnassos
# Processing Record 41 of the Set 6 | saint-augustin
# Processing Record 42 of the Set 6 | constitucion
# Processing Record 43 of the Set 6 | hammerfest
# Processing Record 44 of the Set 6 | olafsvik
# Processing Record 45 of the Set 6 | lakatoro
# Processing Record 46 of the Set 6 | yelan
# Processing Record 47 of the Set 6 | ciudad del maiz
# Processing Record 48 of the Set 6 | mount gambier
# Processing Record 49 of the Set 6 | skelleftea
# Processing Record 50 of the Set 6 | yar-sale
# Processing Record 1 of the Set 7 | andenes
# Processing Record 2 of the Set 7 | bridgwater
# Processing Record 3 of the Set 7 | saint-pierre
# Processing Record 4 of the Set 7 | giurgeni
# Processing Record 5 of the Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 6 of the Set 7 | port hardy
# Processing Record 7 of the Set 7 | asuncion
# Processing Record 8 of the Set 7 | tepalcatepec
# Processing Record 9 of the Set 7 | jaisalmer
# Processing Record 10 of the Set 7 | pueblo bello
# Processing Record 11 of the Set 7 | gadwal
# Processing Record 12 of the Set 7 | zhanakorgan
# Processing Record 13 of the Set 7 | georgetown
# Processing Record 14 of the Set 7 | morehead
# Processing Record 15 of the Set 7 | samarai
# Processing Record 16 of the Set 7 | belushya guba
# Processing Record 17 of the Set 7 | vallenar
# Processing Record 18 of the Set 7 | te anau
# Processing Record 19 of the Set 7 | zyryanka
# Processing Record 20 of the Set 7 | burica
# City not found. Skipping...
# Processing Record 21 of the Set 7 | high rock
# Processing Record 22 of the Set 7 | itarema
# Processing Record 23 of the Set 7 | labuhan
# Processing Record 24 of the Set 7 | quatre cocos
# Processing Record 25 of the Set 7 | buin
# Processing Record 26 of the Set 7 | college place
# Processing Record 27 of the Set 7 | neiafu
# Processing Record 28 of the Set 7 | tieling
# Processing Record 29 of the Set 7 | nome
# Processing Record 30 of the Set 7 | halifax
# Processing Record 31 of the Set 7 | cumberland
# Processing Record 32 of the Set 7 | saint george
# Processing Record 33 of the Set 7 | bac lieu
# Processing Record 34 of the Set 7 | kloulklubed
# Processing Record 35 of the Set 7 | lokot
# Processing Record 36 of the Set 7 | cabo san lucas
# Processing Record 37 of the Set 7 | goundam
# Processing Record 38 of the Set 7 | rosita
# Processing Record 39 of the Set 7 | lebu
# Processing Record 40 of the Set 7 | tomatlan
# Processing Record 41 of the Set 7 | abu dhabi
# Processing Record 42 of the Set 7 | bakel
# Processing Record 43 of the Set 7 | omsukchan
# Processing Record 44 of the Set 7 | caravelas
# Processing Record 45 of the Set 7 | norrtalje
# Processing Record 46 of the Set 7 | nyurba
# Processing Record 47 of the Set 7 | naze
# Processing Record 48 of the Set 7 | bossangoa
# City not found. Skipping...
# Processing Record 49 of the Set 7 | san policarpo
# City not found. Skipping...
# Processing Record 50 of the Set 7 | mambajao
# City not found. Skipping...
# Processing Record 1 of the Set 8 | faxinal
# Processing Record 2 of the Set 8 | dikson
# Processing Record 3 of the Set 8 | shenzhen
# Processing Record 4 of the Set 8 | bilibino
# Processing Record 5 of the Set 8 | sungaipenuh
# Processing Record 6 of the Set 8 | deputatskiy
# Processing Record 7 of the Set 8 | opuwo
# Processing Record 8 of the Set 8 | shashi
# Processing Record 9 of the Set 8 | chillicothe
# Processing Record 10 of the Set 8 | namibe
# Processing Record 11 of the Set 8 | grenada
# Processing Record 12 of the Set 8 | bermeo
# Processing Record 13 of the Set 8 | piryion
# Processing Record 14 of the Set 8 | piacabucu
# Processing Record 15 of the Set 8 | port blair
# Processing Record 16 of the Set 8 | naryan-mar
# Processing Record 17 of the Set 8 | srednekolymsk
# Processing Record 18 of the Set 8 | aasiaat
# Processing Record 19 of the Set 8 | pallisa
# Processing Record 20 of the Set 8 | faya
# Processing Record 21 of the Set 8 | kilindoni
# Processing Record 22 of the Set 8 | santa cruz
# Processing Record 23 of the Set 8 | kazbegi
# City not found. Skipping...
# Processing Record 24 of the Set 8 | yatou
# Processing Record 25 of the Set 8 | urumqi
# Processing Record 26 of the Set 8 | richards bay
# Processing Record 27 of the Set 8 | ambovombe
# City not found. Skipping...
# Processing Record 28 of the Set 8 | dwarka
# Processing Record 29 of the Set 8 | avera
# Processing Record 30 of the Set 8 | victoria
# Processing Record 31 of the Set 8 | letnyaya stavka
# Processing Record 32 of the Set 8 | villa bruzual
# Processing Record 33 of the Set 8 | prainha
# Processing Record 34 of the Set 8 | coahuayana
# Processing Record 35 of the Set 8 | kodiak
# Processing Record 36 of the Set 8 | juifang
# City not found. Skipping...
# Processing Record 37 of the Set 8 | warqla
# Processing Record 38 of the Set 8 | lompoc
# Processing Record 39 of the Set 8 | san carlos de bariloche
# Processing Record 40 of the Set 8 | wanaka
# Processing Record 41 of the Set 8 | miyang
# Processing Record 42 of the Set 8 | aktau
# Processing Record 43 of the Set 8 | kabinda
# Processing Record 44 of the Set 8 | chaman
# Processing Record 45 of the Set 8 | medina
# Processing Record 46 of the Set 8 | vamosgyork
# Processing Record 47 of the Set 8 | kalmar
# Processing Record 48 of the Set 8 | san quintin
# Processing Record 49 of the Set 8 | guspini
# Processing Record 50 of the Set 8 | ileza
# Processing Record 1 of the Set 9 | luorong
# Processing Record 2 of the Set 9 | praia da vitoria
# Processing Record 3 of the Set 9 | nantucket
# Processing Record 4 of the Set 9 | maloy
# Processing Record 5 of the Set 9 | lamar
# Processing Record 6 of the Set 9 | sorvag
# City not found. Skipping...
# Processing Record 7 of the Set 9 | lagunas
# Processing Record 8 of the Set 9 | meadow lake
# Processing Record 9 of the Set 9 | inhambane
# Processing Record 10 of the Set 9 | carnarvon
# Processing Record 11 of the Set 9 | silver city
# Processing Record 12 of the Set 9 | palma soriano
# Processing Record 13 of the Set 9 | lasa
# Processing Record 14 of the Set 9 | tidore
# Processing Record 15 of the Set 9 | bengkalis
# Processing Record 16 of the Set 9 | gimli
# Processing Record 17 of the Set 9 | shahreza
# Processing Record 18 of the Set 9 | lobau
# Processing Record 19 of the Set 9 | hasaki
# Processing Record 20 of the Set 9 | tawnat
# City not found. Skipping...
# Processing Record 21 of the Set 9 | nanortalik
# Processing Record 22 of the Set 9 | poltavka
# Processing Record 23 of the Set 9 | hamilton
# Processing Record 24 of the Set 9 | palu
# Processing Record 25 of the Set 9 | isabela
# Processing Record 26 of the Set 9 | okandja
# City not found. Skipping...
# Processing Record 27 of the Set 9 | jimeta
# Processing Record 28 of the Set 9 | batticaloa
# Processing Record 29 of the Set 9 | whitehorse
# Processing Record 30 of the Set 9 | isangel
# Processing Record 31 of the Set 9 | grand gaube
# Processing Record 32 of the Set 9 | soyo
# Processing Record 33 of the Set 9 | maneadero
# Processing Record 34 of the Set 9 | christchurch
# Processing Record 35 of the Set 9 | bowen
# Processing Record 36 of the Set 9 | dunedin
# Processing Record 37 of the Set 9 | minas
# Processing Record 38 of the Set 9 | oranjemund
# Processing Record 39 of the Set 9 | bonavista
# Processing Record 40 of the Set 9 | kuytun
# Processing Record 41 of the Set 9 | phumi samraong
# City not found. Skipping...
# Processing Record 42 of the Set 9 | bubaque
# Processing Record 43 of the Set 9 | boda
# City not found. Skipping...
# Processing Record 44 of the Set 9 | tarrafal
# Processing Record 45 of the Set 9 | shimoga
# Processing Record 46 of the Set 9 | karkaralinsk
# Processing Record 47 of the Set 9 | san martin
# Processing Record 48 of the Set 9 | udachnyy
# Processing Record 49 of the Set 9 | whitehaven
# Processing Record 50 of the Set 9 | chase
# Processing Record 1 of the Set 10 | lumphat
# City not found. Skipping...
# Processing Record 2 of the Set 10 | sumbe
# Processing Record 3 of the Set 10 | kang
# Processing Record 4 of the Set 10 | atar
# Processing Record 5 of the Set 10 | iquique
# Processing Record 6 of the Set 10 | inuvik
# Processing Record 7 of the Set 10 | duzce
# Processing Record 8 of the Set 10 | wilkie
# Processing Record 9 of the Set 10 | plettenberg bay
# Processing Record 10 of the Set 10 | tubruq
# Processing Record 11 of the Set 10 | sao joao evangelista
# Processing Record 12 of the Set 10 | manggar
# Processing Record 13 of the Set 10 | los zacatones
# Processing Record 14 of the Set 10 | lerwick
# Processing Record 15 of the Set 10 | hobyo
# Processing Record 16 of the Set 10 | santa maria del oro
# Processing Record 17 of the Set 10 | lukovetskiy
# Processing Record 18 of the Set 10 | havre-saint-pierre
# Processing Record 19 of the Set 10 | karratha
# Processing Record 20 of the Set 10 | luwuk
# Processing Record 21 of the Set 10 | beli manastir
# Processing Record 22 of the Set 10 | chiang khong
# Processing Record 23 of the Set 10 | bumba
# Processing Record 24 of the Set 10 | khandbari
# Processing Record 25 of the Set 10 | ko samui
# Processing Record 26 of the Set 10 | kavaratti
# Processing Record 27 of the Set 10 | provideniya
# Processing Record 28 of the Set 10 | chabahar
# Processing Record 29 of the Set 10 | luganville
# Processing Record 30 of the Set 10 | high level
# Processing Record 31 of the Set 10 | enid
# Processing Record 32 of the Set 10 | presidente medici
# Processing Record 33 of the Set 10 | pochutla
# Processing Record 34 of the Set 10 | itarantim
# Processing Record 35 of the Set 10 | salinopolis
# Processing Record 36 of the Set 10 | visby
# Processing Record 37 of the Set 10 | kutum
# Processing Record 38 of the Set 10 | anuradhapura
# Processing Record 39 of the Set 10 | la macarena
# Processing Record 40 of the Set 10 | vao
# Processing Record 41 of the Set 10 | yining
# Processing Record 42 of the Set 10 | eureka
# Processing Record 43 of the Set 10 | netishyn
# Processing Record 44 of the Set 10 | namatanai
# Processing Record 45 of the Set 10 | teya
# Processing Record 46 of the Set 10 | letterkenny
# Processing Record 47 of the Set 10 | purpe
# Processing Record 48 of the Set 10 | baishishan
# Processing Record 49 of the Set 10 | kigoma
# Processing Record 50 of the Set 10 | nabire
# Processing Record 1 of the Set 11 | panacan
# City not found. Skipping...
# Processing Record 2 of the Set 11 | alaverdi
# Processing Record 3 of the Set 11 | inderborskiy
# Processing Record 4 of the Set 11 | muroto
# Processing Record 5 of the Set 11 | quelimane
# Processing Record 6 of the Set 11 | sarangani
# City not found. Skipping...
# Processing Record 7 of the Set 11 | terrasini
# Processing Record 8 of the Set 11 | borogontsy
# Processing Record 9 of the Set 11 | tutoia
# Processing Record 10 of the Set 11 | innisfail
# Processing Record 11 of the Set 11 | pasni
# Processing Record 12 of the Set 11 | makung
# City not found. Skipping...
# Processing Record 13 of the Set 11 | tashtyp
# Processing Record 14 of the Set 11 | jasper
# Processing Record 15 of the Set 11 | manokwari
# Processing Record 16 of the Set 11 | japura
# Processing Record 17 of the Set 11 | tucuman
# Processing Record 18 of the Set 11 | saldanha
# Processing Record 19 of the Set 11 | lakselv
# Processing Record 20 of the Set 11 | maniitsoq
# Processing Record 21 of the Set 11 | yichang
# Processing Record 22 of the Set 11 | sao felix do xingu
# Processing Record 23 of the Set 11 | ulladulla
# Processing Record 24 of the Set 11 | kalaleh
# Processing Record 25 of the Set 11 | boueni
# Processing Record 26 of the Set 11 | barbacoas
# Processing Record 27 of the Set 11 | paamiut
# Processing Record 28 of the Set 11 | yeniseysk
# Processing Record 29 of the Set 11 | yuzhno-yeniseyskiy
# Processing Record 30 of the Set 11 | shaartuz
# City not found. Skipping...
# Processing Record 31 of the Set 11 | solovetskiy
# Processing Record 32 of the Set 11 | nuuk
# Processing Record 33 of the Set 11 | umm kaddadah
# Processing Record 34 of the Set 11 | mlonggo
# Processing Record 35 of the Set 11 | rio gallegos
# Processing Record 36 of the Set 11 | belyy yar
# Processing Record 37 of the Set 11 | jasper
# Processing Record 38 of the Set 11 | louisbourg
# Processing Record 39 of the Set 11 | hami
# Processing Record 40 of the Set 11 | gorele
# Processing Record 41 of the Set 11 | blonie
# Processing Record 42 of the Set 11 | sisimiut
# Processing Record 43 of the Set 11 | san cristobal
# Processing Record 44 of the Set 11 | naraini
# Processing Record 45 of the Set 11 | bentiu
# Processing Record 46 of the Set 11 | honningsvag
# Processing Record 47 of the Set 11 | rincon
# Processing Record 48 of the Set 11 | tura
# Processing Record 49 of the Set 11 | palmer
# Processing Record 50 of the Set 11 | aswan
# Processing Record 1 of the Set 12 | vila velha
# Processing Record 2 of the Set 12 | nadym
# Processing Record 3 of the Set 12 | puerto del rosario
# Processing Record 4 of the Set 12 | yulara
# Processing Record 5 of the Set 12 | concepcion del oro
# Processing Record 6 of the Set 12 | safranbolu
# Processing Record 7 of the Set 12 | merke
# Processing Record 8 of the Set 12 | karaul
# Processing Record 9 of the Set 12 | rantepao
# Processing Record 10 of the Set 12 | atambua
# Processing Record 11 of the Set 12 | le mars
# Processing Record 12 of the Set 12 | pandan
# Processing Record 13 of the Set 12 | pilar
# Processing Record 14 of the Set 12 | wahiawa
# Processing Record 15 of the Set 12 | biak
# Processing Record 16 of the Set 12 | faanui
# Processing Record 17 of the Set 12 | bababe
# Processing Record 18 of the Set 12 | lucknow
# Processing Record 19 of the Set 12 | alappuzha
# Processing Record 20 of the Set 12 | aripuana
# Processing Record 21 of the Set 12 | kaeo
# Processing Record 22 of the Set 12 | taoudenni
# Processing Record 23 of the Set 12 | laredo
# Processing Record 24 of the Set 12 | alto longa
# Processing Record 25 of the Set 12 | kargasok
# Processing Record 26 of the Set 12 | henties bay
# Processing Record 27 of the Set 12 | esperance
# Processing Record 28 of the Set 12 | rossland
# Processing Record 29 of the Set 12 | skibbereen
# Processing Record 30 of the Set 12 | chernyshevskiy
# Processing Record 31 of the Set 12 | souillac
# Processing Record 32 of the Set 12 | netivot
# Processing Record 33 of the Set 12 | egvekinot
# Processing Record 34 of the Set 12 | anloga
# Processing Record 35 of the Set 12 | merauke
# Processing Record 36 of the Set 12 | san jeronimo
# Processing Record 37 of the Set 12 | aksu
# Processing Record 38 of the Set 12 | vaasa
# Processing Record 39 of the Set 12 | motygino
# Processing Record 40 of the Set 12 | strezhevoy
# Processing Record 41 of the Set 12 | fecamp
# Processing Record 42 of the Set 12 | cockburn town
# Processing Record 43 of the Set 12 | yablonovo
# Processing Record 44 of the Set 12 | mitsamiouli
# Processing Record 45 of the Set 12 | utiroa
# Processing Record 46 of the Set 12 | ostrovnoy
# Processing Record 47 of the Set 12 | ratzeburg
# Processing Record 48 of the Set 12 | gazanjyk
# Processing Record 49 of the Set 12 | san luis
# Processing Record 50 of the Set 12 | launceston
# Processing Record 1 of the Set 13 | basco
# Processing Record 2 of the Set 13 | ksenyevka
# Processing Record 3 of the Set 13 | guilin
# Processing Record 4 of the Set 13 | fairmont
# Processing Record 5 of the Set 13 | college
# Processing Record 6 of the Set 13 | bratsk
# Processing Record 7 of the Set 13 | kaohsiung
# City not found. Skipping...
# Processing Record 8 of the Set 13 | sulangan
# Processing Record 9 of the Set 13 | palafrugell
# Processing Record 10 of the Set 13 | conceicao do araguaia
# Processing Record 11 of the Set 13 | voh
# Processing Record 12 of the Set 13 | anadyr
# Processing Record 13 of the Set 13 | prince rupert
# Processing Record 14 of the Set 13 | entebbe
# Processing Record 15 of the Set 13 | jieshi
# Processing Record 16 of the Set 13 | villaviciosa
# Processing Record 17 of the Set 13 | leh
# Processing Record 18 of the Set 13 | saryshagan
# Processing Record 19 of the Set 13 | westport
# Processing Record 20 of the Set 13 | sorland
# Processing Record 21 of the Set 13 | vila
# Processing Record 22 of the Set 13 | zhigansk
# Processing Record 23 of the Set 13 | ukiah
# Processing Record 24 of the Set 13 | bandarbeyla
# Processing Record 25 of the Set 13 | siocon
# Processing Record 26 of the Set 13 | tabuk
# Processing Record 27 of the Set 13 | marsa matruh
# Processing Record 28 of the Set 13 | torres
# Processing Record 29 of the Set 13 | yetkul
# Processing Record 30 of the Set 13 | wajir
# Processing Record 31 of the Set 13 | abaza
# Processing Record 32 of the Set 13 | ardon
# Processing Record 33 of the Set 13 | miahuatlan
# Processing Record 34 of the Set 13 | lethem
# Processing Record 35 of the Set 13 | muravlenko
# Processing Record 36 of the Set 13 | barroualie
# City not found. Skipping...
# Processing Record 37 of the Set 13 | the valley
# Processing Record 38 of the Set 13 | shar
# Processing Record 39 of the Set 13 | sandwick
# Processing Record 40 of the Set 13 | ulcinj
# Processing Record 41 of the Set 13 | sao jose da coroa grande
# Processing Record 42 of the Set 13 | labytnangi
# Processing Record 43 of the Set 13 | saint-paul
# Processing Record 44 of the Set 13 | marquette
# Processing Record 45 of the Set 13 | hutchinson
# Processing Record 46 of the Set 13 | tucumcari
# Processing Record 47 of the Set 13 | sur
# Processing Record 48 of the Set 13 | bullhead city
# Processing Record 49 of the Set 13 | port-gentil
# City not found. Skipping...
# Processing Record 50 of the Set 13 | charters towers
# Processing Record 1 of the Set 14 | varzelandia
# Processing Record 2 of the Set 14 | tilichiki
# Processing Record 3 of the Set 14 | broken hill
# Processing Record 4 of the Set 14 | yangjiang
# Processing Record 5 of the Set 14 | baruun-urt
# Processing Record 6 of the Set 14 | siyabuswa
# Processing Record 7 of the Set 14 | fremont
# Processing Record 8 of the Set 14 | carberry
# Processing Record 9 of the Set 14 | shakawe
# Processing Record 10 of the Set 14 | belozerskoye
# Processing Record 11 of the Set 14 | beringovskiy
# Processing Record 12 of the Set 14 | tambovka
# Processing Record 13 of the Set 14 | tamiahua
# Processing Record 14 of the Set 14 | ugoofaaru
# Processing Record 15 of the Set 14 | guozhen
# Processing Record 16 of the Set 14 | macau
# Processing Record 17 of the Set 14 | kaltasy
# Processing Record 18 of the Set 14 | gilgit
# Processing Record 19 of the Set 14 | kuandian
# Processing Record 20 of the Set 14 | bur gabo
# Processing Record 21 of the Set 14 | auki
# Processing Record 22 of the Set 14 | nemuro
# Processing Record 23 of the Set 14 | dudinka
# Processing Record 24 of the Set 14 | koyilandi
# Processing Record 25 of the Set 14 | iberia
# Processing Record 26 of the Set 14 | vila franca do campo
# Processing Record 27 of the Set 14 | korhogo
# Processing Record 28 of the Set 14 | bataipora
# Processing Record 29 of the Set 14 | kibala
# Processing Record 30 of the Set 14 | burdur
# Processing Record 31 of the Set 14 | kawalu
# Processing Record 32 of the Set 14 | gravdal
# Processing Record 33 of the Set 14 | bardiyah
# Processing Record 34 of the Set 14 | aldan
# Processing Record 35 of the Set 14 | peace river
# Processing Record 36 of the Set 14 | pemberton
# Processing Record 37 of the Set 14 | springbok
# Processing Record 38 of the Set 14 | atarra
# Processing Record 39 of the Set 14 | pio ix
# Processing Record 40 of the Set 14 | dubti
# Processing Record 41 of the Set 14 | korla
# Processing Record 42 of the Set 14 | noumea
# Processing Record 43 of the Set 14 | nova olimpia
# Processing Record 44 of the Set 14 | banda aceh
# Processing Record 45 of the Set 14 | saint-ambroise
# Processing Record 46 of the Set 14 | moose factory
# Processing Record 47 of the Set 14 | masty
# Processing Record 48 of the Set 14 | mattawa
# Processing Record 49 of the Set 14 | viedma
# Processing Record 50 of the Set 14 | letlhakane
# Processing Record 1 of the Set 15 | mahajanga
# Processing Record 2 of the Set 15 | taitung
# City not found. Skipping...
# Processing Record 3 of the Set 15 | berlevag
# Processing Record 4 of the Set 15 | benbrook
# Processing Record 5 of the Set 15 | homer
# Processing Record 6 of the Set 15 | abu samrah
# Processing Record 7 of the Set 15 | anchorage
# Processing Record 8 of the Set 15 | shimoda
# Processing Record 9 of the Set 15 | seminole
# Processing Record 10 of the Set 15 | ilorin
# Processing Record 11 of the Set 15 | fengrun
# Processing Record 12 of the Set 15 | mehamn
# Processing Record 13 of the Set 15 | ponta do sol
# Processing Record 14 of the Set 15 | obo
# Processing Record 15 of the Set 15 | san juan del sur
# Processing Record 16 of the Set 15 | satipo
# Processing Record 17 of the Set 15 | alekseyevka
# Processing Record 18 of the Set 15 | cruzilia
# Processing Record 19 of the Set 15 | manadhoo
# Processing Record 20 of the Set 15 | champerico
# Processing Record 21 of the Set 15 | ribas do rio pardo
# Processing Record 22 of the Set 15 | saint-francois
# Processing Record 23 of the Set 15 | porto novo
# Processing Record 24 of the Set 15 | itacare
# Processing Record 25 of the Set 15 | grants
# Processing Record 26 of the Set 15 | acajutla
# Processing Record 27 of the Set 15 | marawi
# Processing Record 28 of the Set 15 | eckernforde
# Processing Record 29 of the Set 15 | tromso
# Processing Record 30 of the Set 15 | ejutla de crespo
# Processing Record 31 of the Set 15 | mergui
# City not found. Skipping...
# Processing Record 32 of the Set 15 | mapiripan
# Processing Record 33 of the Set 15 | carutapera
# Processing Record 34 of the Set 15 | general roca
# Processing Record 35 of the Set 15 | bria
# Processing Record 36 of the Set 15 | hoi an
# Processing Record 37 of the Set 15 | kathu
# Processing Record 38 of the Set 15 | tornio
# Processing Record 39 of the Set 15 | wanning
# Processing Record 40 of the Set 15 | new baltimore
# Processing Record 41 of the Set 15 | jatai
# Processing Record 42 of the Set 15 | surt
# Processing Record 43 of the Set 15 | alta floresta
# Processing Record 44 of the Set 15 | anaconda
# Processing Record 45 of the Set 15 | omaruru
# Processing Record 46 of the Set 15 | oxelosund
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 706

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Jumla      NP  29.2747   82.1838     45.34        41           0
# 1     Pombia      IT  45.6530    8.6336     52.25        80           0
# 2    Ushuaia      AR -54.8000  -68.3000     38.86        70          20
# 3  Busselton      AU -33.6500  115.3333     67.68        72          92
# 4      Vaini      TO -21.2000 -175.2000     82.56        89          75
#
#    Wind Speed Current Description
# 0        4.83           clear sky
# 1        3.44           clear sky
# 2       11.50          few clouds
# 3        9.24     overcast clouds
# 4        4.61       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
