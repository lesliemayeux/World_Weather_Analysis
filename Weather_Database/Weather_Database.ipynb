# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats= np.random.uniform(-90.000,90.000, size=2000)
lngs=np.random.uniform(-90.000,90.000,size=2000)
lats_lngs= zip(lats,lngs)
lats_lngs

# %%
#Add lats and longs list
coordinates=list(lats_lngs)

# %%
# Use the citipy module to determine city based on lat/long
from citipy import citipy

# %%
# Create a list for holding the cities
cities=[]
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique add to the list
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficient count
len(cities)
# Out:
# 773

# %%
# Import the requests library
import requests
#Import the API Key
from config import weather_api_key

# %%
#Define URL

url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Creat an empty list to hold the weather data
city_data=[]
#print the beginning of the logging 
print("Beginning Data Retrieval   ")
print("---------------------------")
#create counters
record_count=1
set_count=1
# Out:
# Beginning Data Retrieval
# ---------------------------

# %%
#Loop through all the cities in our list
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50==0 and i>=50):
        set_count+=1
        record_count=1
    #Create endpoint URL with each city
    city_url= url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count+=1
#Run an API request for each of the cities
    try:
    #Parse the JSON and retrieve data
        city_weather= requests.get(city_url).json()
        #parse out the needed data
        city_lat=city_weather["coord"]["lat"]
        city_lng=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity= city_weather["main"]["humidity"]
        city_clouds= city_weather["clouds"]["all"]
        city_wind= city_weather["wind"]["speed"]
        city_country=city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description":city_description})
                          
        #If an error is experienced, skip the city
    
    except KeyError:
        print("City not found. Skipping...")
        pass
    #Indicate the Data Loading is complete
print("-------------------------------")
print("Data Retrieval Complete        ")
print("-------------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | nuuk
# Processing Record 5 of Set 1 | suez
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | presidente epitacio
# Processing Record 8 of Set 1 | mananara
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | srivardhan
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | aripuana
# Processing Record 13 of Set 1 | sabzevar
# Processing Record 14 of Set 1 | henties bay
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | uray
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | takoradi
# Processing Record 22 of Set 1 | houlton
# Processing Record 23 of Set 1 | port blair
# Processing Record 24 of Set 1 | kautokeino
# Processing Record 25 of Set 1 | sidi ali
# Processing Record 26 of Set 1 | parrita
# Processing Record 27 of Set 1 | narsaq
# Processing Record 28 of Set 1 | geraldton
# Processing Record 29 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 1 | cariacica
# Processing Record 31 of Set 1 | abha
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | cayenne
# Processing Record 36 of Set 1 | gombe
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | thinadhoo
# Processing Record 39 of Set 1 | manta
# Processing Record 40 of Set 1 | lodja
# Processing Record 41 of Set 1 | gornoye loo
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | jacmel
# Processing Record 44 of Set 1 | camocim
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | road town
# Processing Record 47 of Set 1 | santa cruz
# Processing Record 48 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 1 | dutse
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | yashkul
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | kwekwe
# Processing Record 4 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 2 | jalu
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | nantucket
# Processing Record 8 of Set 2 | gurupi
# Processing Record 9 of Set 2 | staryy nadym
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | moussoro
# Processing Record 13 of Set 2 | ornskoldsvik
# Processing Record 14 of Set 2 | cyangugu
# Processing Record 15 of Set 2 | mana
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | urumqi
# Processing Record 18 of Set 2 | mirina
# City not found. Skipping...
# Processing Record 19 of Set 2 | kashan
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | kangaatsiaq
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | dzilam gonzalez
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | bousso
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | ilo
# Processing Record 31 of Set 2 | calabozo
# Processing Record 32 of Set 2 | brigantine
# Processing Record 33 of Set 2 | yining
# Processing Record 34 of Set 2 | ballinasloe
# Processing Record 35 of Set 2 | vila franca do campo
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | sao filipe
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | samokov
# Processing Record 40 of Set 2 | grindavik
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | valdivia
# Processing Record 43 of Set 2 | caravelas
# Processing Record 44 of Set 2 | narasannapeta
# Processing Record 45 of Set 2 | faro
# Processing Record 46 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 2 | plettenberg bay
# Processing Record 48 of Set 2 | paamiut
# Processing Record 49 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 2 | zhanaozen
# Processing Record 1 of Set 3 | begunitsy
# Processing Record 2 of Set 3 | nanortalik
# Processing Record 3 of Set 3 | kutum
# Processing Record 4 of Set 3 | sao jose da coroa grande
# Processing Record 5 of Set 3 | odweyne
# Processing Record 6 of Set 3 | geresk
# City not found. Skipping...
# Processing Record 7 of Set 3 | neulengbach
# Processing Record 8 of Set 3 | soyo
# Processing Record 9 of Set 3 | codrington
# Processing Record 10 of Set 3 | trairi
# Processing Record 11 of Set 3 | megara
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | hofn
# Processing Record 14 of Set 3 | mogadishu
# Processing Record 15 of Set 3 | hagere selam
# Processing Record 16 of Set 3 | maceio
# Processing Record 17 of Set 3 | sao joao da barra
# Processing Record 18 of Set 3 | pangnirtung
# Processing Record 19 of Set 3 | gibara
# Processing Record 20 of Set 3 | muros
# Processing Record 21 of Set 3 | ostrov
# Processing Record 22 of Set 3 | ruwi
# Processing Record 23 of Set 3 | wolow
# Processing Record 24 of Set 3 | shubarkuduk
# Processing Record 25 of Set 3 | timbiqui
# Processing Record 26 of Set 3 | saint george
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | redwater
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | develi
# Processing Record 32 of Set 3 | sorland
# Processing Record 33 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 34 of Set 3 | mwingi
# Processing Record 35 of Set 3 | sao felix do xingu
# Processing Record 36 of Set 3 | mecca
# Processing Record 37 of Set 3 | kot diji
# Processing Record 38 of Set 3 | salalah
# Processing Record 39 of Set 3 | virginia beach
# Processing Record 40 of Set 3 | tazovskiy
# Processing Record 41 of Set 3 | uyuni
# Processing Record 42 of Set 3 | petropavlovka
# Processing Record 43 of Set 3 | tikrit
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | halifax
# Processing Record 46 of Set 3 | ati
# Processing Record 47 of Set 3 | ramasukha
# City not found. Skipping...
# Processing Record 48 of Set 3 | frankfort
# Processing Record 49 of Set 3 | filadelfia
# Processing Record 50 of Set 3 | tromso
# Processing Record 1 of Set 4 | manzil salim
# Processing Record 2 of Set 4 | conde
# Processing Record 3 of Set 4 | bileca
# Processing Record 4 of Set 4 | aliwal north
# Processing Record 5 of Set 4 | buedu
# Processing Record 6 of Set 4 | sur
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | strezhevoy
# Processing Record 9 of Set 4 | rochegda
# Processing Record 10 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 11 of Set 4 | stornoway
# Processing Record 12 of Set 4 | zalha
# Processing Record 13 of Set 4 | malakal
# Processing Record 14 of Set 4 | souillac
# Processing Record 15 of Set 4 | praia da vitoria
# Processing Record 16 of Set 4 | hudiksvall
# Processing Record 17 of Set 4 | santa catalina
# Processing Record 18 of Set 4 | moose factory
# Processing Record 19 of Set 4 | priiskovyy
# Processing Record 20 of Set 4 | saint-augustin
# Processing Record 21 of Set 4 | los llanos de aridane
# Processing Record 22 of Set 4 | quelimane
# Processing Record 23 of Set 4 | veraval
# Processing Record 24 of Set 4 | boa vista
# Processing Record 25 of Set 4 | goderich
# Processing Record 26 of Set 4 | longyearbyen
# Processing Record 27 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 4 | berlevag
# Processing Record 29 of Set 4 | touros
# Processing Record 30 of Set 4 | velingara
# Processing Record 31 of Set 4 | paita
# Processing Record 32 of Set 4 | portree
# Processing Record 33 of Set 4 | chimbote
# Processing Record 34 of Set 4 | west bay
# Processing Record 35 of Set 4 | talcahuano
# Processing Record 36 of Set 4 | daryapur
# Processing Record 37 of Set 4 | ventspils
# Processing Record 38 of Set 4 | marawi
# Processing Record 39 of Set 4 | kungsbacka
# Processing Record 40 of Set 4 | somerset west
# Processing Record 41 of Set 4 | tutin
# Processing Record 42 of Set 4 | jardim
# Processing Record 43 of Set 4 | gien
# Processing Record 44 of Set 4 | ankazobe
# Processing Record 45 of Set 4 | vestmannaeyjar
# Processing Record 46 of Set 4 | saint-francois
# Processing Record 47 of Set 4 | perry
# Processing Record 48 of Set 4 | carnarvon
# Processing Record 49 of Set 4 | sokoni
# Processing Record 50 of Set 4 | kudahuvadhoo
# Processing Record 1 of Set 5 | amudat
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | senador jose porfirio
# Processing Record 4 of Set 5 | voineasa
# Processing Record 5 of Set 5 | abnub
# Processing Record 6 of Set 5 | matagami
# Processing Record 7 of Set 5 | esik
# Processing Record 8 of Set 5 | gryazovets
# Processing Record 9 of Set 5 | tahoua
# Processing Record 10 of Set 5 | breznice
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | betki
# City not found. Skipping...
# Processing Record 13 of Set 5 | ambilobe
# Processing Record 14 of Set 5 | san cristobal
# Processing Record 15 of Set 5 | polyarnyy
# Processing Record 16 of Set 5 | nieuw amsterdam
# Processing Record 17 of Set 5 | agadez
# Processing Record 18 of Set 5 | namibe
# Processing Record 19 of Set 5 | inongo
# Processing Record 20 of Set 5 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 22 of Set 5 | bonthe
# Processing Record 23 of Set 5 | chipata
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | klaksvik
# Processing Record 26 of Set 5 | tiznit
# Processing Record 27 of Set 5 | riyadh
# Processing Record 28 of Set 5 | rottenmann
# Processing Record 29 of Set 5 | santa cruz do rio pardo
# Processing Record 30 of Set 5 | pokaran
# Processing Record 31 of Set 5 | punta arenas
# Processing Record 32 of Set 5 | vila velha
# Processing Record 33 of Set 5 | saidpur
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | kulhudhuffushi
# Processing Record 36 of Set 5 | uppsala
# Processing Record 37 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 5 | angra dos reis
# Processing Record 39 of Set 5 | leshukonskoye
# Processing Record 40 of Set 5 | gornopravdinsk
# Processing Record 41 of Set 5 | westport
# Processing Record 42 of Set 5 | pitsunda
# Processing Record 43 of Set 5 | sisimiut
# Processing Record 44 of Set 5 | semey
# Processing Record 45 of Set 5 | vallenar
# Processing Record 46 of Set 5 | ouadda
# Processing Record 47 of Set 5 | awjilah
# Processing Record 48 of Set 5 | tessalit
# Processing Record 49 of Set 5 | port shepstone
# Processing Record 50 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 6 | hun
# Processing Record 2 of Set 6 | kristiinankaupunki
# Processing Record 3 of Set 6 | victoria
# Processing Record 4 of Set 6 | grand gaube
# Processing Record 5 of Set 6 | saint-georges
# Processing Record 6 of Set 6 | manacapuru
# Processing Record 7 of Set 6 | ugoofaaru
# Processing Record 8 of Set 6 | cape coast
# Processing Record 9 of Set 6 | balykshi
# Processing Record 10 of Set 6 | rio grande
# Processing Record 11 of Set 6 | asyut
# Processing Record 12 of Set 6 | kamenka
# Processing Record 13 of Set 6 | canaries
# Processing Record 14 of Set 6 | calamar
# Processing Record 15 of Set 6 | krasnoye
# Processing Record 16 of Set 6 | siguiri
# Processing Record 17 of Set 6 | hobyo
# Processing Record 18 of Set 6 | kabare
# Processing Record 19 of Set 6 | hualmay
# Processing Record 20 of Set 6 | hopatcong
# Processing Record 21 of Set 6 | taltal
# Processing Record 22 of Set 6 | buenos aires
# Processing Record 23 of Set 6 | zafra
# Processing Record 24 of Set 6 | rawson
# Processing Record 25 of Set 6 | faya
# Processing Record 26 of Set 6 | acarau
# Processing Record 27 of Set 6 | ghanzi
# Processing Record 28 of Set 6 | dalbandin
# Processing Record 29 of Set 6 | nouadhibou
# Processing Record 30 of Set 6 | hastings
# Processing Record 31 of Set 6 | bud
# Processing Record 32 of Set 6 | neuquen
# Processing Record 33 of Set 6 | monrovia
# Processing Record 34 of Set 6 | bury saint edmunds
# City not found. Skipping...
# Processing Record 35 of Set 6 | usinsk
# Processing Record 36 of Set 6 | gopalpur
# Processing Record 37 of Set 6 | dingle
# Processing Record 38 of Set 6 | novyye lyady
# Processing Record 39 of Set 6 | kisanga
# Processing Record 40 of Set 6 | pontes e lacerda
# Processing Record 41 of Set 6 | kruisfontein
# Processing Record 42 of Set 6 | biltine
# Processing Record 43 of Set 6 | sembe
# Processing Record 44 of Set 6 | muzhi
# Processing Record 45 of Set 6 | richards bay
# Processing Record 46 of Set 6 | idah
# Processing Record 47 of Set 6 | gogrial
# Processing Record 48 of Set 6 | san luis
# Processing Record 49 of Set 6 | lima
# Processing Record 50 of Set 6 | jumla
# Processing Record 1 of Set 7 | inhambane
# Processing Record 2 of Set 7 | skjervoy
# Processing Record 3 of Set 7 | rorvik
# Processing Record 4 of Set 7 | llangefni
# Processing Record 5 of Set 7 | sambava
# Processing Record 6 of Set 7 | taywarah
# Processing Record 7 of Set 7 | vredendal
# Processing Record 8 of Set 7 | drezdenko
# Processing Record 9 of Set 7 | guzelyurt
# Processing Record 10 of Set 7 | havelock
# Processing Record 11 of Set 7 | conceicao do araguaia
# Processing Record 12 of Set 7 | gobabis
# Processing Record 13 of Set 7 | esfahan
# Processing Record 14 of Set 7 | la asuncion
# Processing Record 15 of Set 7 | uaua
# Processing Record 16 of Set 7 | chopinzinho
# Processing Record 17 of Set 7 | soure
# Processing Record 18 of Set 7 | talawdi
# City not found. Skipping...
# Processing Record 19 of Set 7 | zatyshshya
# Processing Record 20 of Set 7 | saint-pierre
# Processing Record 21 of Set 7 | sabha
# Processing Record 22 of Set 7 | coruripe
# Processing Record 23 of Set 7 | khaniotis
# Processing Record 24 of Set 7 | itirucu
# Processing Record 25 of Set 7 | manicore
# Processing Record 26 of Set 7 | qasigiannguit
# Processing Record 27 of Set 7 | mwinilunga
# Processing Record 28 of Set 7 | brus laguna
# Processing Record 29 of Set 7 | madaoua
# Processing Record 30 of Set 7 | doha
# Processing Record 31 of Set 7 | dunmore town
# Processing Record 32 of Set 7 | capalnita
# Processing Record 33 of Set 7 | kandi
# Processing Record 34 of Set 7 | alta floresta
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | maralal
# Processing Record 37 of Set 7 | eyl
# Processing Record 38 of Set 7 | rio gallegos
# Processing Record 39 of Set 7 | mampong
# Processing Record 40 of Set 7 | sucre
# Processing Record 41 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 7 | cuenca
# Processing Record 43 of Set 7 | kavaratti
# Processing Record 44 of Set 7 | portalegre
# Processing Record 45 of Set 7 | elat
# Processing Record 46 of Set 7 | cockburn town
# Processing Record 47 of Set 7 | ostrovnoy
# Processing Record 48 of Set 7 | likasi
# Processing Record 49 of Set 7 | comodoro rivadavia
# Processing Record 50 of Set 7 | vulcanesti
# Processing Record 1 of Set 8 | makushino
# Processing Record 2 of Set 8 | abu samrah
# Processing Record 3 of Set 8 | vitoria da conquista
# Processing Record 4 of Set 8 | shelburne
# Processing Record 5 of Set 8 | mbandaka
# Processing Record 6 of Set 8 | saint anthony
# Processing Record 7 of Set 8 | makat
# Processing Record 8 of Set 8 | camacha
# Processing Record 9 of Set 8 | nouakchott
# Processing Record 10 of Set 8 | semnan
# Processing Record 11 of Set 8 | menongue
# Processing Record 12 of Set 8 | manjacaze
# Processing Record 13 of Set 8 | male
# Processing Record 14 of Set 8 | santa maria
# Processing Record 15 of Set 8 | le port
# Processing Record 16 of Set 8 | visby
# Processing Record 17 of Set 8 | panjab
# Processing Record 18 of Set 8 | hashtrud
# Processing Record 19 of Set 8 | aguimes
# Processing Record 20 of Set 8 | zapolyarnyy
# Processing Record 21 of Set 8 | sao gabriel da cachoeira
# Processing Record 22 of Set 8 | melchor de mencos
# Processing Record 23 of Set 8 | pangody
# Processing Record 24 of Set 8 | dieppe
# Processing Record 25 of Set 8 | yuryev-polskiy
# Processing Record 26 of Set 8 | oksfjord
# Processing Record 27 of Set 8 | aburi
# Processing Record 28 of Set 8 | derzhavinsk
# Processing Record 29 of Set 8 | ajdabiya
# Processing Record 30 of Set 8 | olkhovka
# Processing Record 31 of Set 8 | olafsvik
# Processing Record 32 of Set 8 | arica
# Processing Record 33 of Set 8 | olyka
# Processing Record 34 of Set 8 | yar-sale
# Processing Record 35 of Set 8 | tazmalt
# Processing Record 36 of Set 8 | peniche
# Processing Record 37 of Set 8 | yandyki
# Processing Record 38 of Set 8 | boralday
# Processing Record 39 of Set 8 | antequera
# Processing Record 40 of Set 8 | tall kayf
# Processing Record 41 of Set 8 | sioux lookout
# Processing Record 42 of Set 8 | torfyanoy
# Processing Record 43 of Set 8 | sechura
# Processing Record 44 of Set 8 | chicama
# Processing Record 45 of Set 8 | axim
# Processing Record 46 of Set 8 | vadakku valliyur
# Processing Record 47 of Set 8 | bilma
# Processing Record 48 of Set 8 | krasnyy klyuch
# Processing Record 49 of Set 8 | asfi
# Processing Record 50 of Set 8 | hambantota
# Processing Record 1 of Set 9 | rafaela
# Processing Record 2 of Set 9 | andenes
# Processing Record 3 of Set 9 | san carlos de bariloche
# Processing Record 4 of Set 9 | puerto leguizamo
# Processing Record 5 of Set 9 | ivanava
# Processing Record 6 of Set 9 | itarema
# Processing Record 7 of Set 9 | leh
# Processing Record 8 of Set 9 | karasjok
# Processing Record 9 of Set 9 | maragogi
# Processing Record 10 of Set 9 | amapa
# Processing Record 11 of Set 9 | vardo
# Processing Record 12 of Set 9 | villa del rosario
# Processing Record 13 of Set 9 | loukhi
# Processing Record 14 of Set 9 | keetmanshoop
# Processing Record 15 of Set 9 | yarada
# Processing Record 16 of Set 9 | cape elizabeth
# City not found. Skipping...
# Processing Record 17 of Set 9 | at-bashi
# Processing Record 18 of Set 9 | marsa matruh
# Processing Record 19 of Set 9 | aquiraz
# Processing Record 20 of Set 9 | bollnas
# Processing Record 21 of Set 9 | gorele
# Processing Record 22 of Set 9 | trudarmeyskiy
# Processing Record 23 of Set 9 | verkhnyaya inta
# Processing Record 24 of Set 9 | tyulgan
# Processing Record 25 of Set 9 | kouroussa
# Processing Record 26 of Set 9 | bartica
# Processing Record 27 of Set 9 | honningsvag
# Processing Record 28 of Set 9 | tvoroyri
# Processing Record 29 of Set 9 | lagoa
# Processing Record 30 of Set 9 | viedma
# Processing Record 31 of Set 9 | arlit
# Processing Record 32 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 33 of Set 9 | abapo
# Processing Record 34 of Set 9 | derazhnya
# Processing Record 35 of Set 9 | baherden
# Processing Record 36 of Set 9 | pionerskiy
# Processing Record 37 of Set 9 | ortona
# Processing Record 38 of Set 9 | george
# Processing Record 39 of Set 9 | seminole
# Processing Record 40 of Set 9 | hendek
# Processing Record 41 of Set 9 | channel-port aux basques
# Processing Record 42 of Set 9 | ponta delgada
# Processing Record 43 of Set 9 | kobryn
# Processing Record 44 of Set 9 | margate
# Processing Record 45 of Set 9 | gbarnga
# Processing Record 46 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 47 of Set 9 | bonga
# Processing Record 48 of Set 9 | pangoa
# Processing Record 49 of Set 9 | mitsamiouli
# Processing Record 50 of Set 9 | storsteinnes
# Processing Record 1 of Set 10 | rostaq
# City not found. Skipping...
# Processing Record 2 of Set 10 | vagur
# Processing Record 3 of Set 10 | neftcala
# Processing Record 4 of Set 10 | inta
# Processing Record 5 of Set 10 | yusva
# City not found. Skipping...
# Processing Record 6 of Set 10 | tevriz
# Processing Record 7 of Set 10 | shediac
# Processing Record 8 of Set 10 | ancud
# Processing Record 9 of Set 10 | saa
# Processing Record 10 of Set 10 | elliot
# Processing Record 11 of Set 10 | bako
# Processing Record 12 of Set 10 | adeje
# Processing Record 13 of Set 10 | huarmey
# Processing Record 14 of Set 10 | cruden bay
# City not found. Skipping...
# Processing Record 15 of Set 10 | constitucion
# Processing Record 16 of Set 10 | kashi
# Processing Record 17 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 18 of Set 10 | parrsboro
# Processing Record 19 of Set 10 | dondo
# Processing Record 20 of Set 10 | kafue
# Processing Record 21 of Set 10 | bodden town
# Processing Record 22 of Set 10 | altamira
# Processing Record 23 of Set 10 | kidal
# Processing Record 24 of Set 10 | rosario
# Processing Record 25 of Set 10 | senno
# Processing Record 26 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 27 of Set 10 | gilgil
# City not found. Skipping...
# Processing Record 28 of Set 10 | chapais
# Processing Record 29 of Set 10 | chichawatni
# Processing Record 30 of Set 10 | gaya
# Processing Record 31 of Set 10 | ghatsila
# Processing Record 32 of Set 10 | san andres
# Processing Record 33 of Set 10 | mayahi
# Processing Record 34 of Set 10 | knysna
# Processing Record 35 of Set 10 | corner brook
# Processing Record 36 of Set 10 | bure
# Processing Record 37 of Set 10 | uruzgan
# Processing Record 38 of Set 10 | murten
# Processing Record 39 of Set 10 | curvelo
# Processing Record 40 of Set 10 | arvika
# Processing Record 41 of Set 10 | blagoyevo
# Processing Record 42 of Set 10 | cay
# Processing Record 43 of Set 10 | digha
# Processing Record 44 of Set 10 | alakurtti
# Processing Record 45 of Set 10 | kuvshinovo
# Processing Record 46 of Set 10 | farafangana
# Processing Record 47 of Set 10 | coquimbo
# Processing Record 48 of Set 10 | verkhnyaya toyma
# Processing Record 49 of Set 10 | petukhovo
# Processing Record 50 of Set 10 | dholka
# Processing Record 1 of Set 11 | aneho
# Processing Record 2 of Set 11 | mayumba
# Processing Record 3 of Set 11 | salamanca
# Processing Record 4 of Set 11 | el bordo
# Processing Record 5 of Set 11 | casablanca
# Processing Record 6 of Set 11 | alenquer
# Processing Record 7 of Set 11 | bandarbeyla
# Processing Record 8 of Set 11 | ellisras
# Processing Record 9 of Set 11 | zastron
# Processing Record 10 of Set 11 | gidam
# Processing Record 11 of Set 11 | okitipupa
# Processing Record 12 of Set 11 | sol-iletsk
# Processing Record 13 of Set 11 | sharkan
# Processing Record 14 of Set 11 | batticaloa
# Processing Record 15 of Set 11 | sumbuya
# Processing Record 16 of Set 11 | kinkala
# Processing Record 17 of Set 11 | visnes
# Processing Record 18 of Set 11 | livani
# Processing Record 19 of Set 11 | marzuq
# Processing Record 20 of Set 11 | lasa
# Processing Record 21 of Set 11 | maniitsoq
# Processing Record 22 of Set 11 | shache
# Processing Record 23 of Set 11 | valparaiso
# Processing Record 24 of Set 11 | mazamari
# Processing Record 25 of Set 11 | volkhov
# Processing Record 26 of Set 11 | beisfjord
# Processing Record 27 of Set 11 | harper
# Processing Record 28 of Set 11 | emba
# Processing Record 29 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 30 of Set 11 | madimba
# Processing Record 31 of Set 11 | ekibastuz
# Processing Record 32 of Set 11 | thunder bay
# Processing Record 33 of Set 11 | makaryev
# Processing Record 34 of Set 11 | bara
# Processing Record 35 of Set 11 | waddan
# Processing Record 36 of Set 11 | pryazha
# Processing Record 37 of Set 11 | mercedes
# Processing Record 38 of Set 11 | severnyy
# Processing Record 39 of Set 11 | telhara
# Processing Record 40 of Set 11 | betare oya
# Processing Record 41 of Set 11 | mucurapo
# Processing Record 42 of Set 11 | aranos
# Processing Record 43 of Set 11 | taoudenni
# Processing Record 44 of Set 11 | banikoara
# Processing Record 45 of Set 11 | boende
# Processing Record 46 of Set 11 | gazli
# Processing Record 47 of Set 11 | jacareacanga
# Processing Record 48 of Set 11 | saint-joseph
# Processing Record 49 of Set 11 | susehri
# Processing Record 50 of Set 11 | hurghada
# Processing Record 1 of Set 12 | coihaique
# Processing Record 2 of Set 12 | turayf
# Processing Record 3 of Set 12 | la serena
# Processing Record 4 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 12 | bay roberts
# Processing Record 6 of Set 12 | duz
# City not found. Skipping...
# Processing Record 7 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 8 of Set 12 | gusau
# Processing Record 9 of Set 12 | naron
# Processing Record 10 of Set 12 | aswan
# Processing Record 11 of Set 12 | carutapera
# Processing Record 12 of Set 12 | hadrut
# Processing Record 13 of Set 12 | vieste
# Processing Record 14 of Set 12 | alindao
# Processing Record 15 of Set 12 | trincomalee
# Processing Record 16 of Set 12 | zheleznodorozhnyy
# Processing Record 17 of Set 12 | saint-denis
# Processing Record 18 of Set 12 | nalut
# Processing Record 19 of Set 12 | palora
# Processing Record 20 of Set 12 | borlange
# City not found. Skipping...
# Processing Record 21 of Set 12 | humberto de campos
# Processing Record 22 of Set 12 | kuusamo
# Processing Record 23 of Set 12 | sagua la grande
# Processing Record 24 of Set 12 | chirongui
# Processing Record 25 of Set 12 | johi
# Processing Record 26 of Set 12 | livingston
# Processing Record 27 of Set 12 | bakhchysaray
# Processing Record 28 of Set 12 | pocone
# Processing Record 29 of Set 12 | mwanza
# Processing Record 30 of Set 12 | nybro
# Processing Record 31 of Set 12 | camabatela
# Processing Record 32 of Set 12 | galich
# Processing Record 33 of Set 12 | ploemeur
# Processing Record 34 of Set 12 | wagar
# Processing Record 35 of Set 12 | pokhara
# Processing Record 36 of Set 12 | bursa
# Processing Record 37 of Set 12 | lonevag
# Processing Record 38 of Set 12 | biu
# Processing Record 39 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 40 of Set 12 | werda
# Processing Record 41 of Set 12 | zholymbet
# Processing Record 42 of Set 12 | madawaska
# Processing Record 43 of Set 12 | svetlyy
# Processing Record 44 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 45 of Set 12 | norrtalje
# Processing Record 46 of Set 12 | belmonte
# Processing Record 47 of Set 12 | prainha
# Processing Record 48 of Set 12 | kattivakkam
# Processing Record 49 of Set 12 | timra
# Processing Record 50 of Set 12 | bandrele
# Processing Record 1 of Set 13 | necochea
# Processing Record 2 of Set 13 | aguada de pasajeros
# Processing Record 3 of Set 13 | padang
# Processing Record 4 of Set 13 | umm lajj
# Processing Record 5 of Set 13 | magog
# Processing Record 6 of Set 13 | lethem
# Processing Record 7 of Set 13 | adrar
# Processing Record 8 of Set 13 | buncrana
# Processing Record 9 of Set 13 | pedernales
# Processing Record 10 of Set 13 | paramonga
# Processing Record 11 of Set 13 | fayetteville
# Processing Record 12 of Set 13 | peterhead
# Processing Record 13 of Set 13 | charlestown
# Processing Record 14 of Set 13 | atar
# Processing Record 15 of Set 13 | vite
# Processing Record 16 of Set 13 | donskoye
# Processing Record 17 of Set 13 | sarakhs
# Processing Record 18 of Set 13 | gat
# Processing Record 19 of Set 13 | borborema
# Processing Record 20 of Set 13 | puerto carreno
# Processing Record 21 of Set 13 | kopyevo
# City not found. Skipping...
# Processing Record 22 of Set 13 | aksu
# Processing Record 23 of Set 13 | oktyabrskoye
# Processing Record 24 of Set 13 | aden
# Processing Record 25 of Set 13 | conceicao da barra
# Processing Record 26 of Set 13 | bridgetown
# Processing Record 27 of Set 13 | mutis
# Processing Record 28 of Set 13 | sovetskiy
# Processing Record 29 of Set 13 | okahandja
# Processing Record 30 of Set 13 | husavik
# Processing Record 31 of Set 13 | gao
# Processing Record 32 of Set 13 | cotonou
# Processing Record 33 of Set 13 | senanga
# Processing Record 34 of Set 13 | angoche
# Processing Record 35 of Set 13 | tucuman
# Processing Record 36 of Set 13 | saint-michel-des-saints
# Processing Record 37 of Set 13 | los arabos
# Processing Record 38 of Set 13 | shahrud
# Processing Record 39 of Set 13 | tchaourou
# Processing Record 40 of Set 13 | ilorin
# Processing Record 41 of Set 13 | chiredzi
# Processing Record 42 of Set 13 | marsh harbour
# Processing Record 43 of Set 13 | linhares
# Processing Record 44 of Set 13 | kabwe
# Processing Record 45 of Set 13 | marathon
# Processing Record 46 of Set 13 | abu dhabi
# Processing Record 47 of Set 13 | turukhansk
# Processing Record 48 of Set 13 | sakakah
# Processing Record 49 of Set 13 | togur
# Processing Record 50 of Set 13 | salinopolis
# Processing Record 1 of Set 14 | liwale
# Processing Record 2 of Set 14 | jadu
# Processing Record 3 of Set 14 | tabou
# Processing Record 4 of Set 14 | oistins
# Processing Record 5 of Set 14 | san nicola
# Processing Record 6 of Set 14 | buraydah
# Processing Record 7 of Set 14 | letterkenny
# Processing Record 8 of Set 14 | fort oglethorpe
# Processing Record 9 of Set 14 | stepnyak
# Processing Record 10 of Set 14 | warri
# Processing Record 11 of Set 14 | vyritsa
# Processing Record 12 of Set 14 | neokhoropoulon
# City not found. Skipping...
# Processing Record 13 of Set 14 | martos
# Processing Record 14 of Set 14 | libreville
# Processing Record 15 of Set 14 | moyo
# Processing Record 16 of Set 14 | ulyanovo
# City not found. Skipping...
# Processing Record 17 of Set 14 | semenivka
# Processing Record 18 of Set 14 | mtwara
# Processing Record 19 of Set 14 | ninotsminda
# Processing Record 20 of Set 14 | belyy yar
# Processing Record 21 of Set 14 | larsnes
# Processing Record 22 of Set 14 | doume
# Processing Record 23 of Set 14 | dalvik
# Processing Record 24 of Set 14 | xai-xai
# Processing Record 25 of Set 14 | damietta
# Processing Record 26 of Set 14 | dosso
# Processing Record 27 of Set 14 | manbij
# Processing Record 28 of Set 14 | agirish
# Processing Record 29 of Set 14 | poltavka
# Processing Record 30 of Set 14 | esil
# Processing Record 31 of Set 14 | nizhnevartovsk
# Processing Record 32 of Set 14 | natal
# Processing Record 33 of Set 14 | bundibugyo
# Processing Record 34 of Set 14 | orasac
# Processing Record 35 of Set 14 | keuruu
# Processing Record 36 of Set 14 | obilnoye
# Processing Record 37 of Set 14 | praia
# Processing Record 38 of Set 14 | salekhard
# Processing Record 39 of Set 14 | pidhorodne
# Processing Record 40 of Set 14 | ferreira do alentejo
# Processing Record 41 of Set 14 | vestmanna
# Processing Record 42 of Set 14 | lucea
# Processing Record 43 of Set 14 | abong mbang
# Processing Record 44 of Set 14 | ripky
# Processing Record 45 of Set 14 | mayor pablo lagerenza
# Processing Record 46 of Set 14 | busia
# Processing Record 47 of Set 14 | klishkivtsi
# Processing Record 48 of Set 14 | porto novo
# Processing Record 49 of Set 14 | korla
# Processing Record 50 of Set 14 | velizh
# Processing Record 1 of Set 15 | seydi
# Processing Record 2 of Set 15 | port-cartier
# Processing Record 3 of Set 15 | sonqor
# Processing Record 4 of Set 15 | weligama
# Processing Record 5 of Set 15 | kargasok
# Processing Record 6 of Set 15 | orumiyeh
# Processing Record 7 of Set 15 | hawalli
# Processing Record 8 of Set 15 | maldonado
# Processing Record 9 of Set 15 | yarmouth
# Processing Record 10 of Set 15 | shalakusha
# Processing Record 11 of Set 15 | dir
# Processing Record 12 of Set 15 | macaparana
# Processing Record 13 of Set 15 | cape girardeau
# Processing Record 14 of Set 15 | loubomo
# Processing Record 15 of Set 15 | roald
# Processing Record 16 of Set 15 | raga
# Processing Record 17 of Set 15 | sokolskoye
# Processing Record 18 of Set 15 | dudinka
# Processing Record 19 of Set 15 | dzerzhinsk
# Processing Record 20 of Set 15 | maimon
# City not found. Skipping...
# Processing Record 21 of Set 15 | buturlino
# Processing Record 22 of Set 15 | santarem
# Processing Record 23 of Set 15 | dhidhdhoo
# Processing Record 24 of Set 15 | lagarto
# Processing Record 25 of Set 15 | bayir
# Processing Record 26 of Set 15 | numan
# Processing Record 27 of Set 15 | vysha
# Processing Record 28 of Set 15 | manoel urbano
# Processing Record 29 of Set 15 | zubtsov
# Processing Record 30 of Set 15 | nikolskoye-na-cheremshane
# City not found. Skipping...
# Processing Record 31 of Set 15 | luanda
# Processing Record 32 of Set 15 | gashua
# Processing Record 33 of Set 15 | wageningen
# Processing Record 34 of Set 15 | afua
# Processing Record 35 of Set 15 | ara
# Processing Record 36 of Set 15 | puerto suarez
# Processing Record 37 of Set 15 | vryburg
# Processing Record 38 of Set 15 | ho
# City not found. Skipping...
# Processing Record 39 of Set 15 | zaqatala
# Processing Record 40 of Set 15 | suwanee
# Processing Record 41 of Set 15 | lannion
# Processing Record 42 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 44 of Set 15 | mutoko
# Processing Record 45 of Set 15 | gazojak
# Processing Record 46 of Set 15 | lahij
# Processing Record 47 of Set 15 | promyshlennaya
# Processing Record 48 of Set 15 | opuwo
# Processing Record 49 of Set 15 | ituango
# Processing Record 50 of Set 15 | yurginskoye
# Processing Record 1 of Set 16 | mehran
# Processing Record 2 of Set 16 | estelle
# Processing Record 3 of Set 16 | valledupar
# Processing Record 4 of Set 16 | punta gorda
# Processing Record 5 of Set 16 | ondjiva
# Processing Record 6 of Set 16 | andijon
# Processing Record 7 of Set 16 | krutinka
# Processing Record 8 of Set 16 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 16 | koungou
# Processing Record 10 of Set 16 | antalaha
# Processing Record 11 of Set 16 | gulshat
# City not found. Skipping...
# Processing Record 12 of Set 16 | kommunisticheskiy
# Processing Record 13 of Set 16 | itanhaem
# Processing Record 14 of Set 16 | kolondieba
# Processing Record 15 of Set 16 | hearst
# Processing Record 16 of Set 16 | norwich
# Processing Record 17 of Set 16 | talara
# Processing Record 18 of Set 16 | beloha
# Processing Record 19 of Set 16 | piacabucu
# Processing Record 20 of Set 16 | terme
# Processing Record 21 of Set 16 | santa marta
# Processing Record 22 of Set 16 | skibbereen
# Processing Record 23 of Set 16 | shakhtinsk
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#           City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Cape Town      ZA -33.9258  18.4232     55.11        92           0
# 1      Iqaluit      CA  63.7506 -68.5145     24.53        79          75
# 2  East London      ZA -33.0153  27.9116     60.10        76           0
# 3         Nuuk      GL  64.1835 -51.7216     34.41        93         100
# 4         Suez      EG  29.9737  32.5263     64.27        69           7
#
#    Wind Speed Current Description
# 0        4.61           clear sky
# 1       13.80       broken clouds
# 2        5.61           clear sky
# 3       15.01     overcast clouds
# 4        8.57           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
